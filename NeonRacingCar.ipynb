# %%
import gym
import universe
import random
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-d7f44a704e37> in <module>
#       1 import gym
# ----> 2 import universe
#       3 import random
#
# ~/universe/universe/__init__.py in <module>
#      18 from gym.envs.registration import register
#      19
# ---> 20 import universe.scoreboard
#      21 import universe.configuration
#      22 from universe import error, envs
#
# ~/universe/universe/scoreboard/__init__.py in <module>
# ----> 1 from gym.benchmarks import scoring
#       2 from gym.benchmarks import register_benchmark
#       3
#       4 register_benchmark(
#       5     id='Atari7VNC-v0',
#
# ModuleNotFoundError: No module named 'gym.benchmarks'

# %%
print(universe.__file__) 
print(universe.register)
print(universe.configuration)
# Out:
# /home/suraj/anaconda3/envs/universe/lib/python3.6/site-packages/universe/__init__.py
# <function register at 0x7f7e68256f28>
# <module 'universe.configuration' from '/home/suraj/anaconda3/envs/universe/lib/python3.6/site-packages/universe/configuration.py'>

# %%
env = gym.make('flashgames.NeonRace-v0')
env.configure(remotes=1)
# Out:
# [2021-01-24 14:28:24,284] Making new env: flashgames.NeonRace-v0
# [2021-01-24 14:28:24,328] Ports used: dict_keys([])
# [2021-01-24 14:28:24,329] [0] Creating container: image=quay.io/openai/universe.flashgames:0.20.28. Run the same thing by hand as: docker run -p 5900:5900 -p 15900:15900 --privileged --cap-add SYS_ADMIN --ipc host quay.io/openai/universe.flashgames:0.20.28
# [2021-01-24 14:28:24,335] Image quay.io/openai/universe.flashgames:0.20.28 not present locally; pulling
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# ~/anaconda3/envs/universe/lib/python3.6/site-packages/docker/client.py in _raise_for_status(self, response, explanation)
#     169         try:
# --> 170             response.raise_for_status()
#     171         except requests.exceptions.HTTPError as e:
#
# ...
